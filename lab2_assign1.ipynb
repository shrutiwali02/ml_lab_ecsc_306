# %%
import numpy as np

# %%
import tensorflow as tf
import numpy
import matplotlib.pyplot as plt
rng = numpy.random

learning_rate = 0.0005
training_epochs1 = 100
training_epochs2 = 500
training_epochs3 = 1000
display_step = 50

# Training Data
train_X = numpy.asarray([1,2,3,4,5])
train_Y = numpy.asarray([6,7,8,9,10])
n_samples = train_X.shape[0]

# tf Graph Input
X = tf.placeholder("float")
Y = tf.placeholder("float")

# Set model weights
theta_1= tf.Variable(rng.randn(), name="weight")
theta_0 = tf.Variable(rng.randn(), name="bias")

# Construct a linear model
pred = tf.add(tf.multiply(X, theta_1), theta_0)

# Mean squared error
cost = tf.reduce_sum(tf.pow(pred-Y, 2))/(2*n_samples)
# Gradient descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)

    # Fit all training data
    for epoch in range(training_epochs1):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "theta_1=", sess.run(theta_1), "theta_0=", sess.run(theta_0))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "theta_1=", sess.run(W), "theta_0=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(theta_1) * train_X + sess.run(theta_0), label='Fitted line')
    plt.legend()
    plt.show()
    
    
     # Fit all training data
    for epoch in range(training_epochs2):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "theta_1=", sess.run(theta_1), "theta_0=", sess.run(theta_0))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "theta_1=", sess.run(W), "theta_0=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(theta_1) * train_X + sess.run(theta_0), label='Fitted line')
    plt.legend()
    plt.show()
    
     # Fit all training data
    for epoch in range(training_epochs3):
        for (x, y) in zip(train_X, train_Y):
            sess.run(optimizer, feed_dict={X: x, Y: y})

        #Display logs per epoch step
        if (epoch+1) % display_step == 0:
            c = sess.run(cost, feed_dict={X: train_X, Y:train_Y})
            print ("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c), \
                "theta_1=", sess.run(theta_1), "theta_0=", sess.run(theta_0))

    print ('Optimization Finished!')
    training_cost = sess.run(cost, feed_dict={X: train_X, Y: train_Y})
    print ("Training cost=", training_cost, "theta_1=", sess.run(W), "theta_0=", sess.run(b), '\n')

    #Graphic display
    plt.plot(train_X, train_Y, 'ro', label='Original data')
    plt.plot(train_X, sess.run(theta_1) * train_X + sess.run(theta_0), label='Fitted line')
    plt.legend()
    plt.show()
# Out:
# Epoch: 0050 cost= 9.039740562 theta_1= 1.26425 theta_0= -0.0282789
# Epoch: 0100 cost= 5.898373604 theta_1= 1.52705 theta_0= 0.0660668
# Optimization Finished!
# Training cost= 5.89837 theta_1= -0.74421 theta_0= 0.423676
# Epoch: 0050 cost= 4.152551651 theta_1= 1.72111 theta_0= 0.141274
# Epoch: 0100 cost= 3.178906918 theta_1= 1.86406 theta_0= 0.202227
# Epoch: 0150 cost= 2.632584095 theta_1= 1.969 theta_0= 0.252556
# Epoch: 0200 cost= 2.322787285 theta_1= 2.04567 theta_0= 0.294962
# Epoch: 0250 cost= 2.143946648 theta_1= 2.10132 theta_0= 0.331455
# Epoch: 0300 cost= 2.037660837 theta_1= 2.14135 theta_0= 0.36353
# Epoch: 0350 cost= 1.971605301 theta_1= 2.16976 theta_0= 0.392297
# Epoch: 0400 cost= 1.927885652 theta_1= 2.18954 theta_0= 0.418583
# Epoch: 0450 cost= 1.896601915 theta_1= 2.2029 theta_0= 0.443004
# Epoch: 0500 cost= 1.872269273 theta_1= 2.21149 theta_0= 0.466016
# Optimization Finished!
# Training cost= 1.87227 theta_1= -0.74421 theta_0= 0.423676
# ...
